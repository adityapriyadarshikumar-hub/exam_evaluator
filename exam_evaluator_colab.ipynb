# %% [markdown]
# # Exam Evaluator on Google Colab
#
# This notebook sets up and runs the exam_evaluator project from GitHub.
#
# **To use GPU for faster OCR (required for Colab):**
# 1. Upload this notebook to Colab: Go to https://colab.research.google.com/ and click "Upload" or "New Notebook" then upload `exam_evaluator_colab.ipynb`
# 2. In Colab, go to Runtime > Change runtime type
# 3. Select "GPU" under Hardware accelerator
# 4. Click Save
# 5. Run the cells
#
# If GPU is not enabled, it will use CPU (slower). The notebook auto-detects and enables GPU in the code if available.

# %%
# Clone the repository
# !git clone https://github.com/adityapriyadarshikumar-hub/exam_evaluator.git
# %cd exam_evaluator
# Out:
# Cloning into 'exam_evaluator'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 42 (delta 5), reused 41 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 272.23 KiB | 1.71 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/exam_evaluator/exam_evaluator

# %%
# Install dependencies
# !pip install -r requirements.txt

# %%
# Set up environment variables (replace with your OpenAI key)
import os
os.environ['OPENAI_API_KEY'] = 'your-openai-api-key-here'  # Replace with actual key

# %%
# GPU will be auto-detected in ocr_engine.py
import torch
if torch.cuda.is_available():
    print("GPU is available. OCR will use GPU.")
else:
    print("GPU not available. Using CPU.")
# Out:
# GPU not available. Using CPU.

# %%
# Check GPU status
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
else:
    print("Using CPU. For GPU, change runtime in Colab to GPU.")

# %%
# Run the app
# !python app.py
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# 2026-01-22 17:02:58,270 - INFO - Starting evaluation
# Traceback (most recent call last):
#   File "/content/exam_evaluator/exam_evaluator/app.py", line 49, in <module>
#     score = evaluate_student(
#             ^^^^^^^^^^^^^^^^^
#   File "/content/exam_evaluator/exam_evaluator/app.py", line 18, in evaluate_student
#     rubric_text = extract_rubric_text(rubric_pdf, subject)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/exam_evaluator/exam_evaluator/rubric/pdf_to_text.py", line 7, in extract_rubric_text
#     raw_text = run_ocr(images)
#                ^^^^^^^^^^^^^^^
#   File "/content/exam_evaluator/exam_evaluator/ocr/ocr_engine.py", line 10, in run_ocr
#     results = reader.readtext(img_np, detail=0)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/easyocr/easyocr.py", line 456, in readtext
# ...

# %%
# !apt-get update
# !apt-get install -y poppler-utils
